# %%
import pandas as pd

# %%
pd.read_csv("surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
survey_df = pd.read_csv("surveys.csv")

# %%
type(survey_df)
# Out:
# pandas.core.frame.DataFrame

# %%
survey_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
survey_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
survey_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
survey_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
survey_df.shape
# Out:
# (35549, 9)

# %%
pd.unique(survey_df['sex'])
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
pd.unique(survey_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
pd.unique(survey_df['plot_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
survey_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
survey_df['weight'].count()
# Out:
# 32283

# %%
survey_df['weight'].quantile(0.5)
# Out:
# 37.0

# %%
sorted = survey_df.groupby('sex')

# %%
sorted.describe()
# Out:
#                     day  hindfoot_length         month       plot_id  \
# sex
# F   count  15690.000000     14894.000000  15690.000000  15690.000000
#     mean      16.007138        28.836780      6.583047     11.440854
#     std        8.271144         9.463789      3.367350      6.870684
#     min        1.000000         7.000000      1.000000      1.000000
#     25%        9.000000        21.000000      4.000000      5.000000
#     50%       16.000000        27.000000      7.000000     12.000000
#     75%       23.000000        36.000000     10.000000     17.000000
#     max       31.000000        64.000000     12.000000     24.000000
# M   count  17348.000000     16476.000000  17348.000000  17348.000000
#     mean      16.184286        29.709578      6.392668     11.098282
#     std        8.199274         9.629246      3.420806      6.728713
#     min        1.000000         2.000000      1.000000      1.000000
# ...

# %%
sorted2 = survey_df.groupby(['sex', 'plot_id'])

# %%
sorted2.describe()
# Out:
#                           day  hindfoot_length       month     record_id  \
# sex plot_id
# F   1       count  848.000000       808.000000  848.000000    848.000000
#             mean    15.338443        31.733911    6.597877  18390.384434
#             std      8.325993         8.894939    3.366246  10469.790852
#             min      1.000000        14.000000    1.000000      9.000000
#             25%      9.000000        22.000000    4.000000   8783.500000
#             50%     15.000000        34.000000    7.000000  19182.500000
#             75%     22.000000        36.000000   10.000000  27691.750000
#             max     31.000000        64.000000   12.000000  35393.000000
#     2       count  970.000000       918.000000  970.000000    970.000000
#             mean    16.288660        30.161220    6.426804  17714.753608
#             std      8.046509         8.677937    3.537694  10300.015076
#             min      1.000000        14.000000    1.000000      3.000000
# ...

# %%
sorted2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# sex plot_id
# F   1        18390.384434  6.597877  15.338443  1990.933962        31.733911
#     2        17714.753608  6.426804  16.288660  1990.449485        30.161220
#     3        19888.783875  6.604703  16.161254  1992.013438        23.774044
#     4        17489.205275  6.442661  15.746560  1990.235092        33.249102
#     5        12280.793169  6.142315  15.722960  1986.485769        28.921844
#     6        19406.503392  6.628223  16.313433  1991.579376        26.981322
#     7        19069.668657  6.385075  15.313433  1991.441791        19.779553
#     8        18920.276190  6.632143  15.836905  1991.267857        32.187578
#     9        16217.497069  6.499414  15.555686  1989.303634        35.126092
#     10       16001.496454  5.588652  16.964539  1989.248227        18.641791
#     11       16994.962287  6.759124  16.283455  1989.836983        32.029299
# ...

# %%
sorted = survey_df.groupby('sex')
sorted.count()
# Out:
#      record_id  month    day   year  plot_id  species_id  hindfoot_length  \
# sex
# F        15690  15690  15690  15690    15690       15690            14894
# M        17348  17348  17348  17348    17348       17348            16476
#
#      weight
# sex
# F     15303
# M     16879

# %%
species_count = survey_df.groupby('species_id')

# %%
species_count.count()
# Out:
#             record_id  month    day   year  plot_id    sex  hindfoot_length  \
# species_id
# AB                303    303    303    303      303      0                0
# AH                437    437    437    437      437      1                2
# AS                  2      2      2      2        2      0                0
# BA                 46     46     46     46       46     45               45
# CB                 50     50     50     50       50      0                0
# CM                 13     13     13     13       13      0                0
# CQ                 16     16     16     16       16      0                0
# CS                  1      1      1      1        1      0                0
# CT                  1      1      1      1        1      0                0
# CU                  1      1      1      1        1      0                0
# CV                  1      1      1      1        1      0                0
# ...

# %%
survey_df('weight5') = survey_df['weight'] * 5
# Out:
#   File "<ipython-input-25-31a4c5b7f793>", line 1
#     survey_df('weight5') = survey_df['weight'] * 5
#                                                   ^
# SyntaxError: can't assign to function call

# %%
# %matplotlib inline

# %%
species_counts = survey_df.groupby('species_id').count()

# %%
species_counts.plot(kind='bar')

# %%
total_count= survey_df['record_id'].groupby(survey_df['plot_id']).nunique()

# %%
total_count
# Out:
# plot_id
# 1     1995
# 2     2194
# 3     1828
# 4     1969
# 5     1194
# 6     1582
# 7      816
# 8     1891
# 9     1936
# 10     469
# 11    1918
# 12    2365
# 13    1538
# 14    1885
# 15    1069
# 16     646
# 17    2039
# 18    1445
# 19    1189
# 20    1390
# 21    1173
# 22    1399
# 23     571
# 24    1048
# dtype: int64
